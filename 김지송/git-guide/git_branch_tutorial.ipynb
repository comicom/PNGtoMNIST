# %% [markdown]
# <a href="https://colab.research.google.com/github/comicom/PNGtoMNIST/blob/master/%EA%B9%80%EC%A7%80%EC%86%A1/git-guide/git_branch_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #github Branch#

# %% [markdown]
# ##Concept##
#
# 동일한 소스코드를 기반으로 서로 다른 작업을 할 때 여러 개발자들이 동시에 다양한 작업을 할 수 있게 만들어 주는 기능
#
# 이후 병합(merge)를 통해 다른 브렌치와 통합 할 수 있음

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * 마스터 브렌치 Master Branch
#   - 자동으로 생성되는 기본 브렌치
#
# * 통합 브렌치 Integration Branch (일반적으로 master)
#   - 언제든지 배포할 수 있는 버전을 만들 수 있어야 하는 브랜치 -> 어플리케이션의 모든 기능이 정상적으로 동작하는 상태인 브랜치
#
# * 토픽 브렌치 Topic Branch
#   - 기능 추가나 버그 수정과 같은 단위 작업을 위한 브랜치
#   - 토픽 브랜치에서 특정 작업이 완료되면 다시 통합 브랜치에 병합하는 방식으로 진행 (피처 브랜치 Feature branch)

# %% [markdown]
# ## Checkout ##

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * HEAD
#   - 현재 사용 중인 브랜치의 선두 부분을 나타내는 이름 (보통 master의 선두)
#   - '~(틸드, 물결기호)'와 '^(캐럿, 삽입기호)'을 사용하여 현재 커밋으로부터 특정 커밋의 위치를 가리킬 수 있음
#   - '~' distance info (세대 앞의 정보를 나타냄)
#   - '^' branch info
# * stash
#   - 파일의 변경 내용을 일시적으로 기록해두는 영역
#   - 커밋 가능한 변경 내용 중에 전환된 브랜치에서도 한 차례 변경이 되어 있는 경우에는 체크아웃에 실패할 수 있어 사용

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Merge and Rebase ##
# 여러 개의 브랜치를 하나로 모을 수 있음

# %% [markdown]
# ### merge ###

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **'fast-forward(빨리 감기) 병합'**
#
# master 브랜치에 변경 내역이 없음
#
# 위 경우, 'bugfix' 브랜치의 이력은 'master' 브랜치의 이력을 모두 포함

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **'merge commit(병합 커밋)'**
#
# 'bugfix' 브랜치를 분기한 이후에 'master' 브랜치에 여러 가지 변경 사항이 적용되는 경우
#
# 병합 완료 후, 통합 브랜치인 'master' 브랜치로 통합된 이력이 생김
#
#
#
# >  *'non fast-forward 병합' 설정을 통해 fast-forward 병합도 통합 이력이 남게 할 수 있음*

# %% [markdown]
# ### rebase ###

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 'master' 브랜치에서 'bugfix' 브랜치를 fast-foward(빨리감기) 병합 하는 것
#
#
# > * **merge** 이력이 복잡해짐
# * **rebase** 이력 단순화, 정확한 이력을 남겨야 할 때 X
#   - 이력을 하나로 모두 모아서 처리하도록 운용할 경우,
#     - 토픽 브랜치에 통합 브랜치의 최신 코드를 적용할 경우에는 rebase 사용
#     - 통합 브랜치에 토픽 브랜치를 불러올 경우에는 우선 rebase 후 merge

# %% [markdown]
# ## example ##

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## appendix ##
# Git의 브랜치 운용 모델 - ["A successful Git branching model"](
#   http://nvie.com/posts/a-successful-git-branching-model/)
#
# * 메인 브랜치(Main branch)
# * 피처 브랜치(Feature branch) 또는 토픽 브랜치(Topic branch)
# * 릴리스 브랜치(Release branch)
# * 핫픽스 브랜치(Hotfix branch)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 상세내용 참조 -> https://backlog.com/git-tutorial/kr/stepup/stepup1_5.html

# %% [markdown]
# ## reference ##
# https://backlog.com/git-tutorial/kr/
